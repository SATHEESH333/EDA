# %% [markdown]
# # Drug classification EDA using Python

# %% [markdown]
# * **Data set description:**This data set contains Age,Gender,Cholestrol level,Bp level ,Drug taken,Na_to_K ratio as a cloumns(features) with 200 entries.
# * **Column Descrption:**
# * Age-Between(9-85)
# * Sex-Male,Female
# * BP-High,Low,Normal
# * cholestrol-High,Normal
# * Drug-DrugX,DrugY,DrugC,DrugA

# %%
#importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading The data set
df=pd.read_csv('drug200.csv')

# %%
#showing The first five columns ans last five collums
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  DrugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  DrugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %% [markdown]
#  **Inference**:in the given data set there are 200 entries with 6 columns

# %%
#showing no of rows and columns
df.shape
# Out:
# (200, 6)

# %%
#showing columns
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
#showing columns data type and non_null count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# **Inference**:all the columns are filled with  200 entries

# %%
#showing the general statistics(mean,min,max,std) of integer typte colums
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
#displaying the general stats for object type columns
df.describe(include='object')
# Out:
#         Sex    BP Cholesterol   Drug
# count   200   200         200    200
# unique    2     3           2      5
# top       M  HIGH        HIGH  DrugY
# freq    104    77         103     91

# %% [markdown]
# # Data cleaning

# %%
#gettting null values counts in each columns
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %% [markdown]
# **Inference:**there are no null values in any of the columns

# %% [markdown]
# # looking for outliers

# %% [markdown]
# # Box plot for Age vs Drug

# %%
#finding outliers in age using box plot
plt.figure(figsize=(10,10)) 
sns.boxplot(x='Drug',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Age'>

# %% [markdown]
# **Inference:**there is no out lier

# %% [markdown]
# # Box plot Na_to_k vs Drug

# %%
plt.figure(figsize=(10,10)) 
sns.boxplot(x='Drug',y='Na_to_K',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Na_to_K'>

# %% [markdown]
# **Inference:**there is a outlier in  drug C

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# # Dist plot for Age column

# %%
#Dist plot for Age column
sns.set_style('darkgrid')
plt.figure(figsize=(10,10)) 
sns.distplot(x=df['Age'],bins=10)
plt.xlabel('Age')
plt.title('Age density and hist plot')
# Out:
# C:\Users\gorla\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Age density and hist plot')

# %% [markdown]
# **Inference:**In the given dataset there are  more people in the age group of(45-50) Range.nearly 14%
# * In the Second place(55-60)naerly 11%

# %% [markdown]
# # Dist plot to Na_to_k column

# %%
#dist plot of Na_to_k ratio
plt.figure(figsize=(10,10))
plt.title(' dist plot na to k Ratio')
sns.distplot(x=df['Na_to_K'])
plt.xlabel('na_t0_K Ratio')
# Out:
# C:\Users\gorla\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'na_t0_K Ratio')

# %% [markdown]
# **Inference**more people having the Na_to_K ratio in between 10-12 nearly 25% and next (12-15)range nearly 20%

# %% [markdown]
# # Bar plot for gender column(counting males and females)

# %%
#histogram of sex column
plt.figure(figsize=(20,10))
sns.countplot(x=df['Sex'])
plt.title('count of males and females')
# Out:
# Text(0.5, 1.0, 'count of males and females')

# %% [markdown]
# **Inference:**there are more  males(approx 52%) than females

# %% [markdown]
# # Bar plot of the BP Column

# %%
#Barplot of BP column
plt.figure(figsize=(20,10))
sns.countplot(x=df['BP'])
plt.title('count of bp')
# Out:
# Text(0.5, 1.0, 'count of bp')

# %% [markdown]
# **Inference:**nearly 40% high bp,nearly 32% low bp,nearly 28% of nor mal bp

# %% [markdown]
# # bar plot of  cholestrol column

# %%
#Bar plot of cholestrol  persons
plt.figure(figsize=(20,10))
sns.countplot(x=df['Cholesterol'])
plt.title('count of cholestrol')
# Out:
# Text(0.5, 1.0, 'count of cholestrol')

# %% [markdown]
# **Inference:**approx 52% of people have high cholestrol

# %% [markdown]
# # Drugs Bar plot

# %%
#count of diff types of drugs
plt.figure(figsize=(20,10))
sns.countplot(x=df['Drug'])
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='count'>

# %% [markdown]
# **Inference:**many people have taken Drug Y approx(47%)

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Swarm plot b/w Age and Drug (Taking  BP as a hue )

# %%
#age range for  particular drug
plt.figure(figsize=(10,10)) 
sns.swarmplot(x='Drug',y='Age',hue='BP',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Age'>

# %% [markdown]
# **Inference:**
# * DrugA can only be taken by the people who has  age <=50.and  having high BP
# * DrugB can only be taken by the people who has the age >50.and having High BP
# * Drug C only taken by low Bp people
# *DruX can only be taken by low BP and Normal Bp  people .

# %% [markdown]
# # Swarm plot b/w Age and Drug (Taking Choleatrol as a hue)

# %%
#age range for  particular drug
plt.figure(figsize=(10,10)) 
sns.swarmplot(x='Drug',y='Age',hue='Cholesterol',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Age'>

# %% [markdown]
# **Inference:**Drug c can only be taken by High cholestrol people

# %% [markdown]
# # Swarm plot Na_to_k vs Drug(Taking hue as a BP)

# %%
#swarm plot Na_to_k vs Drug
plt.figure(figsize=(10,10)) 
sns.swarmplot(x='Drug',y='Na_to_K',hue='BP',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Na_to_K'>

# %% [markdown]
# **Inference:**DrugC,Drugx,drugA and DrugB are only for  people whose Na_to_k ratio <15.
# * Drug Y only can be taken by the people whose Na_to_k was >15
# * Drug C only can be taken by  the people whose Na_to_k was<15 and low BP
# *Drug A only can be taken by  the people whose Na_to_k was<15 and high BP
# *Drug B only can be taken by  the people whose Na_to_k was<15 and high BP

# %% [markdown]
# # Swarm plot Na_to_k vs Drug(Taking hue as a Cholestrol)

# %%
#swarm plot Na_to_k vs Drug
plt.figure(figsize=(10,10)) 
sns.swarmplot(x='Drug',y='Na_to_K',hue='Cholesterol',data=df)
# Out:
# <AxesSubplot:xlabel='Drug', ylabel='Na_to_K'>

# %% [markdown]
# **Inference:**Drug C can only be taken by high cholestrol people

# %% [markdown]
# # Label Encoding

# %%
#label encoding for categeorical columns
from sklearn import preprocessing
model=preprocessing.LabelEncoder()
catcol=df.columns[df.dtypes==object]
df[catcol]=df[catcol].apply(lambda x:model.fit_transform(x))
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   0            0   25.355     0
# 1     47    1   1            0   13.093     3
# 2     47    1   1            0   10.114     3
# 3     28    0   2            0    7.798     4
# 4     61    0   1            0   18.043     0
# ..   ...  ...  ..          ...      ...   ...
# 195   56    0   1            0   11.567     3
# 196   16    1   1            0   12.006     3
# 197   52    1   2            0    9.894     4
# 198   23    1   2            1   14.020     4
# 199   40    0   1            1   11.349     4
#
# [200 rows x 6 columns]

# %% [markdown]
# # Correlation between columns

# %%
#finding corelation between columns if any
df.corr()
# Out:
#                   Age       Sex        BP  Cholesterol   Na_to_K      Drug
# Age          1.000000  0.102027  0.054212    -0.068234 -0.063119  0.041856
# Sex          0.102027  1.000000 -0.007814    -0.008811 -0.125008  0.018239
# BP           0.054212 -0.007814  1.000000    -0.137552 -0.149312  0.419397
# Cholesterol -0.068234 -0.008811 -0.137552     1.000000  0.010000  0.048415
# Na_to_K     -0.063119 -0.125008 -0.149312     0.010000  1.000000 -0.689051
# Drug         0.041856  0.018239  0.419397     0.048415 -0.689051  1.000000

# %%
#heat map for visualizing corelation
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Inference:**Drug(Target) is positively correaling with Age,BP column and negatively c orelating with na_to_k

# %% [markdown]
# # Conclusion

# %% [markdown]
#  This EDA will give some use useful insights to built a suitable model for drug prediction using age ,bp,cholestrol,na_to_k ratio.

# %% [markdown]
# # Steps involved
# * Data set loading
# * Data cleaning
# * univariate analysis
# * Bivariate  analysis
# *Correlation analysis
